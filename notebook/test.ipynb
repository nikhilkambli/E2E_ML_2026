# %%
input='aabbcc'
dict={}
lst=[]

for ch in input:
    if ch in dict:
        dict[ch]=dict.get(ch)+1
    else:
        dict[ch]=1

print(dict)

for key,value in dict.items():
    lst.append(value)

if 1 not in lst:
    print('no unique character')
# Out:
# {'a': 2, 'b': 2, 'c': 2}
# no unique character
